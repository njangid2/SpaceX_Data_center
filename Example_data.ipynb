# %%
"""
Satellite Brightness Calculator

Simple functions to calculate satellite brightness based on solar panel 
power requirements and viewing geometry.
"""

import numpy as np
import data_center

result = data_center.calculate_brightness(
    sat_height=550e3, # in meter
    sat_altitude=45,  # in degree
    sat_azimuth=270, # in degree
    sun_altitude=-15, # in degree
    sun_azimuth=270,  # in degree
    power_kw=100, # in kW
    continuous=False  # 'True' if the above power is for satellite operation only then we will extra power to recharge onboard battery 
)

print(result)
# Out:
# /Users/nayanjangid/Starlink_data center
# Using interpolated chassis
# {'intensity': array([8.92358124e-11]), 'ab_magnitude': array([5.90174172]), 'area': 419.84, 'power_type': 'instantaneous'}
